# %%
import numpy as np
import matplotlib.pyplot as plt
import utils

# %%
epu = utils.generate_radia_model(phase=-25, gap=22)

# %%
field = epu.get_field(x=0, y=0, z=np.linspace(-500, 500, 2000))

# %%
plt.plot(field[:, 0])
